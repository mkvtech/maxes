# %%
# %load_ext autoreload
import pandas as pd
import numpy as np

# %%
# %autoreload
from src.xes.xes_file import XesFile
from src.xes.print_xes_info import PrintXesInfo

# %%
files = [
    "data/BPI_Challenge_2013_closed_problems.xes",

    "data/Activities of daily living of several individuals_1_all/data/activitylog_uci_detailed_labour.xes/activitylog_uci_detailed_labour.xes",
    "data/Activities of daily living of several individuals_1_all/data/activitylog_uci_detailed_weekends.xes/activitylog_uci_detailed_weekends.xes",
    "data/Activities of daily living of several individuals_1_all/data/edited_hh102_labour.xes/edited_hh102_labour.xes",
    "data/Activities of daily living of several individuals_1_all/data/edited_hh102_weekends.xes/edited_hh102_weekends.xes",
    "data/Activities of daily living of several individuals_1_all/data/edited_hh104_labour.xes/edited_hh104_labour.xes",
    "data/Activities of daily living of several individuals_1_all/data/edited_hh104_weekends.xes/edited_hh104_weekends.xes",
    "data/Activities of daily living of several individuals_1_all/data/edited_hh110_labour.xes/edited_hh110_labour.xes",
    "data/Activities of daily living of several individuals_1_all/data/edited_hh110_weekends.xes/edited_hh110_weekends.xes",

    "data/Road_Traffic_Fine_Management_Process_1_all/Road_Traffic_Fine_Management_Process.xes",

    "data/Conformance_Checking_Challenge_2019_1_all/CCC19 - Log XES.xes",

    "data/NASA Crew Exploration Vehicle (CEV) Software Event Log_1_all/data/nasa-cev-1-10-single-trace.xes",
    "data/NASA Crew Exploration Vehicle (CEV) Software Event Log_1_all/data/nasa-cev-1-10-splitted.xes",
    "data/NASA Crew Exploration Vehicle (CEV) Software Event Log_1_all/data/nasa-cev-complete-single-trace.xes",
    "data/NASA Crew Exploration Vehicle (CEV) Software Event Log_1_all/data/nasa-cev-complete-splitted.xes"
]

# %%
for file in files:
    print(f"Reading {file}")
    xes = XesFile.read(file)

    PrintXesInfo.s_print_info(xes)
# Out:
# Reading data/BPI_Challenge_2013_closed_problems.xes
# Traces: 1487, events: 6660
# Events: Average: 4.478816408876933, Min: 1, Max: 35
#
# 11 unique attributes in events:
#             Attribute  Count Presence
#             org:group   6659   100.0%
#      resource country   6659   100.0%
#  organization country   6659   100.0%
#          org:resource   6659   100.0%
# organization involved   6659   100.0%
#              org:role   4581    68.8%
#          concept:name   6659   100.0%
#                impact   6659   100.0%
#               product   6659   100.0%
#  lifecycle:transition   6659   100.0%
#        time:timestamp   6659   100.0%
#
# "time:timestamp": 100.0% presence
# average:      2011-11-01 09:52:43.071171328+00:00
# min:          2006-01-11 14:49:42+00:00
# max:          2012-05-31 21:49:06+00:00
# average span: 178 days 21:14:13.334229992
#
# "concept:name": 100.0% presence, 4 different values, top 4:
# ...

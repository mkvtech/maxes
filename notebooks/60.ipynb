# %%
# %load_ext autoreload
import datetime
# import ete3
import itertools
import json
import logging
import math
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import typing
# import re
import xml.etree.ElementTree as ET
# import xml.dom.minidom
# import xmlschema

# %%
# %autoreload
from maxes.xes_loader2 import XesLoader, XesLog
# from maxes.xes_file import XesFile
# from maxes.analyze_xes import AnalyzeXes
# import maxes.analyze_sequence
# import maxes.serialization.serialize
# import maxes.graphs
import maxes.notebooks.utils
import maxes.data.load_files
import maxes.utils
from maxes.generators.xes_generator.xes_generator3 import XesGenerator3 as XesGenerator

# %%
maxes.notebooks.utils.init_notebook()  # RUN ONLY ONCE

# %%
import logging

formatter = logging.Formatter()

consoleHandler = logging.StreamHandler()
consoleHandler.setLevel(logging.DEBUG)
consoleHandler.setFormatter(formatter)

logger = logging.getLogger()
logger.addHandler(consoleHandler)

# %%
def prepare(file_path):
    loader = XesLoader()
    log = loader.load(file_path)

    rng = np.random.default_rng(1)

    generator = XesGenerator(rng=rng)
    generator.fit(log)

    return loader, log, generator

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold


def evaluate_accuracy_score(
    log: XesLog,
    attribute_generator,
    random_state: int,
    kfold_splits: int = 5,
):

    kfold = KFold(n_splits=kfold_splits, shuffle=True, random_state=random_state)
    df = log.df
    X, y = attribute_generator.split_xy(df)

    # attribute_generator.model.fit_transformers(X, y)

    scores = []
    for train_index, val_index in kfold.split(X):
        X_train = X.iloc[train_index].reset_index(drop=True)
        y_train = y.iloc[train_index].reset_index(drop=True)
        X_test = X.iloc[val_index].reset_index(drop=True)
        y_test = y.iloc[val_index].reset_index(drop=True)

        attribute_generator.model.fit(X_train, y_train)
        y_pred = attribute_generator.model.predict(X_test)
        score = accuracy_score(y_test, y_pred)

        scores.append(score)

    return np.mean(scores)


def evaluate_attribute_accuracy_score(
    attribute: str,
    log: XesLog,
    generator: XesGenerator,
):
    attribute_generator = generator.event_attributes_info[attribute].predictor
    min_categories = log.df[attribute].nunique()
    attribute_generator.model.inner_model_kwargs = {"min_categories": min_categories}
    score = evaluate_accuracy_score(
        log=log,
        attribute_generator=attribute_generator,
        random_state=1,
        kfold_splits=5,
    )

    return score

# %% [markdown]
# # bpic2020

# %%
file_path = maxes.data.load_files.get_path__bpic2020__request_for_payment()

loader, log, generator = prepare(file_path)
log.df
# Out:
#   start;    Loading XML
#   complete;    Loading XML
#   start;    Removing namespaces from XML file
#   complete;    Removing namespaces from XML file
#   start;    Collecting XML traces
#   complete;    Collecting XML traces
#   start;    Collecting XML events
#   complete;    Collecting XML events
#   start;    Validating
#   complete;    Validating
#   start;    Gathering meta data
#   complete;    Gathering meta data
#   start;    Fitting models for traces beginning timestamps
#   complete;    Fitting models for traces beginning timestamps
#   start;    Analysing sequence graph
#   complete;    Analysing sequence graph
#   start;    Fitting graph traverser
#   complete;    Fitting graph traverser
#   start;    Fittig models for time:timestamp attribute
#   complete;    Fittig models for time:timestamp attribute
#   start;    Collecting stats
#   complete;    Collecting stats
#   start;    Collecting attributes info
#   complete;    Collecting attributes info
#   start;    Fitting presence models
#   complete;    Fitting presence models
#   start;    Fitting trace-level attributes models
#   complete;    Fitting trace-level attributes models
#   start;    Fitting event-level attributes models
#     start;      Fitting model for id
#       start;      Fitting transformers for id
#       complete;      Fitting transformers for id
#       start;      Fitting prediction model for id
#       complete;      Fitting prediction model for id
#     complete;      Fitting model for id
#     start;      Fitting model for org:resource
#       start;      Fitting transformers for org:resource
#       complete;      Fitting transformers for org:resource
#       start;      Fitting prediction model for org:resource
#       complete;      Fitting prediction model for org:resource
#     complete;      Fitting model for org:resource
#     start;      Fitting model for org:role
#       start;      Fitting transformers for org:role
#       complete;      Fitting transformers for org:role
#       start;      Fitting prediction model for org:role
#       complete;      Fitting prediction model for org:role
#     complete;      Fitting model for org:role
#   complete;    Fitting event-level attributes models
#     case:concept:name                                      concept:name  \
# 0                   1         Request For Payment SUBMITTED by EMPLOYEE
# 1                   1  Request For Payment FINAL_APPROVED by SUPERVISOR
# 2                   1           Request For Payment REJECTED by MISSING
# 3                   1         Request For Payment SUBMITTED by EMPLOYEE
# 4                   1      Request For Payment APPROVED by PRE_APPROVER
# ..                ...                                               ...
# 1                6886    Request For Payment APPROVED by ADMINISTRATION
# 2                6886      Request For Payment APPROVED by BUDGET OWNER
# 3                6886  Request For Payment FINAL_APPROVED by SUPERVISOR
# 4                6886                                   Request Payment
# 5                6886                                   Payment Handled
#
#               time:timestamp                                id  org:resource  \
# 0  2017-01-09 08:17:18+00:00                  st_step 148220_0  STAFF MEMBER
# 1  2017-01-09 08:18:00+00:00                  st_step 148221_0  STAFF MEMBER
# 2  2017-01-10 11:42:32+00:00                  st_step 148222_0  STAFF MEMBER
# 3  2017-03-03 08:51:13+00:00                  st_step 148219_0  STAFF MEMBER
# 4  2017-03-03 08:51:42+00:00                  st_step 148218_0  STAFF MEMBER
# ..                       ...                               ...           ...
# 1  2018-12-29 11:35:02+00:00                  st_step 185004_0  STAFF MEMBER
# 2  2019-01-03 08:27:20+00:00                  st_step 185003_0  STAFF MEMBER
# 3  2019-01-08 08:00:39+00:00                  st_step 185005_0  STAFF MEMBER
# 4  2019-01-08 08:29:14+00:00  rp_request for payment 185000_15        SYSTEM
# 5  2019-01-10 16:31:09+00:00  rp_request for payment 185000_16        SYSTEM
#
#           org:role                 case:Rfp_id    case:Project    case:Task  \
# 0         EMPLOYEE  request for payment 148214  project 148216      UNKNOWN
# 1       SUPERVISOR  request for payment 148214  project 148216      UNKNOWN
# 2          MISSING  request for payment 148214  project 148216      UNKNOWN
# 3         EMPLOYEE  request for payment 148214  project 148216      UNKNOWN
# 4     PRE_APPROVER  request for payment 148214  project 148216      UNKNOWN
# ..             ...                         ...             ...          ...
# 1   ADMINISTRATION  request for payment 185000  project 147860  task 152704
# 2     BUDGET OWNER  request for payment 185000  project 147860  task 152704
# 3       SUPERVISOR  request for payment 185000  project 147860  task 152704
# 4        UNDEFINED  request for payment 185000  project 147860  task 152704
# 5        UNDEFINED  request for payment 185000  project 147860  task 152704
#
#     case:OrganizationalEntity  case:Cost Type  case:RequestedAmount  \
# 0   organizational unit 65463               0             34.336343
# 1   organizational unit 65463               0             34.336343
# 2   organizational unit 65463               0             34.336343
# 3   organizational unit 65463               0             34.336343
# 4   organizational unit 65463               0             34.336343
# ..                        ...             ...                   ...
# 1   organizational unit 65468               0             15.409660
# 2   organizational unit 65468               0             15.409660
# 3   organizational unit 65468               0             15.409660
# 4   organizational unit 65468               0             15.409660
# 5   organizational unit 65468               0             15.409660
#
#    case:Activity                     case:RfpNumber
# 0        UNKNOWN  request for payment number 148215
# 1        UNKNOWN  request for payment number 148215
# 2        UNKNOWN  request for payment number 148215
# 3        UNKNOWN  request for payment number 148215
# 4        UNKNOWN  request for payment number 148215
# ..           ...                                ...
# 1   activity 505  request for payment number 185001
# 2   activity 505  request for payment number 185001
# 3   activity 505  request for payment number 185001
# 4   activity 505  request for payment number 185001
# 5   activity 505  request for payment number 185001
#
# [36796 rows x 14 columns]

# %%
generator.event_attributes_info_df()
# Out:
#              name                     level            xes_type  presence  \
# 0              id  AttributeLevelEnum.EVENT  XesTypeEnum.STRING       1.0
# 1    org:resource  AttributeLevelEnum.EVENT  XesTypeEnum.STRING       1.0
# 2    concept:name                      None  XesTypeEnum.STRING       NaN
# 3  time:timestamp                      None    XesTypeEnum.DATE       NaN
# 4        org:role  AttributeLevelEnum.EVENT  XesTypeEnum.STRING       1.0
#
#   numeralicity is_trace_identifier
# 0         None               False
# 1         None               False
# 2         None                None
# 3         None                None
# 4         None               False

# %%
score__bpic2020 = {
    "org:resource": evaluate_attribute_accuracy_score("org:resource", log, generator),
    "org:role": evaluate_attribute_accuracy_score("org:role", log, generator),
}

score__bpic2020
# Out:
# {'org:resource': np.float64(1.0), 'org:role': np.float64(0.9999184708756506)}

# %% [markdown]
# # env_permit_application_process

# %%
file_path = maxes.data.load_files.get_path__env_permit_application_process__data()

loader, log, generator = prepare(file_path)
log.df
# Out:
#   start;    Loading XML
#   complete;    Loading XML
#   start;    Removing namespaces from XML file
#   complete;    Removing namespaces from XML file
#   start;    Collecting XML traces
#   complete;    Collecting XML traces
#   start;    Collecting XML events
#   complete;    Collecting XML events
#   start;    Validating
#   complete;    Validating
#   start;    Gathering meta data
#   complete;    Gathering meta data
#   start;    Fitting models for traces beginning timestamps
#   complete;    Fitting models for traces beginning timestamps
#   start;    Analysing sequence graph
#   complete;    Analysing sequence graph
#   start;    Fitting graph traverser
#   complete;    Fitting graph traverser
#   start;    Fittig models for time:timestamp attribute
#   complete;    Fittig models for time:timestamp attribute
#   start;    Collecting stats
#   complete;    Collecting stats
#   start;    Collecting attributes info
#   complete;    Collecting attributes info
#   start;    Fitting presence models
#   complete;    Fitting presence models
#   start;    Fitting trace-level attributes models
#   complete;    Fitting trace-level attributes models
#   start;    Fitting event-level attributes models
#     start;      Fitting model for org:group
#       start;      Fitting transformers for org:group
#       complete;      Fitting transformers for org:group
#       start;      Fitting prediction model for org:group
#       complete;      Fitting prediction model for org:group
#     complete;      Fitting model for org:group
#     start;      Fitting model for concept:instance
#       start;      Fitting transformers for concept:instance
#       complete;      Fitting transformers for concept:instance
#       start;      Fitting prediction model for concept:instance
#       complete;      Fitting prediction model for concept:instance
#     complete;      Fitting model for concept:instance
#     start;      Fitting model for org:resource
#       start;      Fitting transformers for org:resource
#       complete;      Fitting transformers for org:resource
#       start;      Fitting prediction model for org:resource
#       complete;      Fitting prediction model for org:resource
#     complete;      Fitting model for org:resource
#   complete;    Fitting event-level attributes models
#     case:concept:name                                concept:name  \
# 0                   1                     Confirmation of receipt
# 1                   1           T02 Check confirmation of receipt
# 2                   1          T03 Adjust confirmation of receipt
# 3                   1           T02 Check confirmation of receipt
# 0                   2                     Confirmation of receipt
# ..                ...                                         ...
# 1                1434           T02 Check confirmation of receipt
# 2                1434       T04 Determine confirmation of receipt
# 3                1434  T05 Print and send confirmation of receipt
# 4                1434      T06 Determine necessity of stop advice
# 5                1434  T10 Determine necessity to stop indication
#
#    lifecycle:transition                   time:timestamp org:group  \
# 0              complete 2011-10-11 11:45:40.276000+00:00   Group 1
# 1              complete 2011-10-12 06:26:25.398000+00:00   Group 4
# 2              complete 2011-11-24 14:36:51.302000+00:00   Group 1
# 3              complete 2011-11-24 14:37:16.553000+00:00   Group 4
# 0              complete 2011-10-18 11:46:39.679000+00:00     EMPTY
# ..                  ...                              ...       ...
# 1              complete 2011-10-18 07:04:48.732000+00:00   Group 4
# 2              complete 2011-10-18 07:05:12.359000+00:00   Group 3
# 3              complete 2011-10-18 07:05:30.196000+00:00   Group 2
# 4              complete 2011-10-18 07:06:01.468000+00:00   Group 1
# 5              complete 2011-10-18 07:06:20.547000+00:00   Group 1
#
#    concept:instance org:resource                   case:startdate  \
# 0        task-42933   Resource21 2011-10-11 11:42:22.688000+00:00
# 1        task-42935   Resource10 2011-10-11 11:42:22.688000+00:00
# 2        task-42957   Resource21 2011-10-11 11:42:22.688000+00:00
# 3        task-47958   Resource21 2011-10-11 11:42:22.688000+00:00
# 0        task-43021   Resource30 2011-10-10 23:06:40.020000+00:00
# ..              ...          ...                              ...
# 1        task-43560   Resource06 2011-10-05 23:06:40.020000+00:00
# 2        task-43562   Resource06 2011-10-05 23:06:40.020000+00:00
# 3        task-43563   Resource06 2011-10-05 23:06:40.020000+00:00
# 4        task-43561   Resource06 2011-10-05 23:06:40.020000+00:00
# 5        task-43564   Resource06 2011-10-05 23:06:40.020000+00:00
#
#    case:responsible             case:enddate_planned case:department  \
# 0        Resource21 2011-12-06 12:41:31.788000+00:00         General
# 1        Resource21 2011-12-06 12:41:31.788000+00:00         General
# 2        Resource21 2011-12-06 12:41:31.788000+00:00         General
# 3        Resource21 2011-12-06 12:41:31.788000+00:00         General
# 0        Resource04 2011-12-06 00:06:40.010000+00:00         General
# ..              ...                              ...             ...
# 1        Resource06 2011-12-01 00:06:40.010000+00:00         General
# 2        Resource06 2011-12-01 00:06:40.010000+00:00         General
# 3        Resource06 2011-12-01 00:06:40.010000+00:00         General
# 4        Resource06 2011-12-01 00:06:40.010000+00:00         General
# 5        Resource06 2011-12-01 00:06:40.010000+00:00         General
#
#    case:group                    case:deadline case:channel  \
# 0     Group 2 2011-12-06 12:41:31.788000+00:00     Internet
# 1     Group 2 2011-12-06 12:41:31.788000+00:00     Internet
# 2     Group 2 2011-12-06 12:41:31.788000+00:00     Internet
# 3     Group 2 2011-12-06 12:41:31.788000+00:00     Internet
# 0     Group 5        2011-12-06 00:06:40+00:00     Internet
# ..        ...                              ...          ...
# 1     Group 5        2011-12-01 00:06:40+00:00     Internet
# 2     Group 5        2011-12-01 00:06:40+00:00     Internet
# 3     Group 5        2011-12-01 00:06:40+00:00     Internet
# 4     Group 5        2011-12-01 00:06:40+00:00     Internet
# 5     Group 5        2011-12-01 00:06:40+00:00     Internet
#
#                        case:enddate
# 0                               NaT
# 1                               NaT
# 2                               NaT
# 3                               NaT
# 0  2011-10-18 11:56:55.943000+00:00
# ..                              ...
# 1  2011-10-20 12:19:44.448000+00:00
# 2  2011-10-20 12:19:44.448000+00:00
# 3  2011-10-20 12:19:44.448000+00:00
# 4  2011-10-20 12:19:44.448000+00:00
# 5  2011-10-20 12:19:44.448000+00:00
#
# [8577 rows x 15 columns]

# %%
generator.event_attributes_info_df()
# Out:
#                    name                     level            xes_type  \
# 0             org:group  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 1      concept:instance  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 2          org:resource  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 3          concept:name                      None  XesTypeEnum.STRING
# 4        time:timestamp                      None    XesTypeEnum.DATE
# 5  lifecycle:transition                      None  XesTypeEnum.STRING
#
#    presence numeralicity is_trace_identifier
# 0       1.0         None               False
# 1       1.0         None               False
# 2       1.0         None               False
# 3       NaN         None                None
# 4       NaN         None                None
# 5       NaN         None                None

# %%
attribute = "org:resource"
attribute_generator = generator.event_attributes_info[attribute].predictor
min_categories = log.df[attribute].nunique()
attribute_generator.model.inner_model_kwargs = {"min_categories": min_categories}
score__org_resource = evaluate_accuracy_score(
    attribute_generator=attribute_generator,
    random_state=1,
    kfold_splits=5,
)

print(score__org_resource)

attribute = "org:group"
attribute_generator = generator.event_attributes_info[attribute].predictor
min_categories = log.df[attribute].nunique()
attribute_generator.model.inner_model_kwargs = {"min_categories": min_categories}
score__org_group = evaluate_accuracy_score(
    attribute_generator=attribute_generator,
    random_state=1,
    kfold_splits=5,
)

print(score__org_group)

attribute = "concept:instance"
attribute_generator = generator.event_attributes_info[attribute].predictor
min_categories = log.df[attribute].nunique()
attribute_generator.model.inner_model_kwargs = {"min_categories": min_categories}
score__concept_instance = evaluate_accuracy_score(
    attribute_generator=attribute_generator,
    random_state=1,
    kfold_splits=5,
)

print(score__concept_instance)
# Out:
# 0.1449233759437841
# 0.857410276798032
# 0.0

# %%
env_permit_application_process_accuracy = {
    "org:resource": score__org_resource,
    "org:group": score__org_group,
    "concept:instance": score__concept_instance,
}
env_permit_application_process_accuracy
# Out:
# {'org:resource': np.float64(0.1449233759437841),
#  'org:group': np.float64(0.857410276798032),
#  'concept:instance': np.float64(0.0)}

# %%
score__env_permit_application_process = {
    "org:resource": evaluate_attribute_accuracy_score("org:resource", log, generator),
    "org:group": evaluate_attribute_accuracy_score("org:group", log, generator),
    # "concept:instance": evaluate_attribute_accuracy_score(
    #     "concept:instance", log, generator
    # ),
}

score__env_permit_application_process
# Out:
# {'org:resource': np.float64(0.1449233759437841),
#  'org:group': np.float64(0.857410276798032)}

# %% [markdown]
# # simple

# %%
file_path = maxes.notebooks.utils.get_data_path("other/simple.xes")

loader, log, generator = prepare(file_path)
log.df
# Out:
#   start;    Loading XML
#   complete;    Loading XML
#   start;    Removing namespaces from XML file
#   complete;    Removing namespaces from XML file
#   start;    Collecting XML traces
#   complete;    Collecting XML traces
#   start;    Collecting XML events
#   complete;    Collecting XML events
#   start;    Validating
#   complete;    Validating
#   start;    Gathering meta data
#   complete;    Gathering meta data
#   start;    Fitting models for traces beginning timestamps
#   complete;    Fitting models for traces beginning timestamps
#   start;    Analysing sequence graph
#   complete;    Analysing sequence graph
#   start;    Fitting graph traverser
#   complete;    Fitting graph traverser
#   start;    Fittig models for time:timestamp attribute
#   complete;    Fittig models for time:timestamp attribute
#   start;    Collecting stats
#   complete;    Collecting stats
#   start;    Collecting attributes info
#   complete;    Collecting attributes info
#   start;    Fitting presence models
#   complete;    Fitting presence models
#   start;    Fitting trace-level attributes models
#   complete;    Fitting trace-level attributes models
#   start;    Fitting event-level attributes models
#     start;      Fitting model for org:resource
#       start;      Fitting transformers for org:resource
#       complete;      Fitting transformers for org:resource
#       start;      Fitting prediction model for org:resource
#       complete;      Fitting prediction model for org:resource
#     complete;      Fitting model for org:resource
#   complete;    Fitting event-level attributes models
#     case:concept:name                                    concept:name  \
# 0                   1                                  incoming claim
# 1                   1  B check if sufficient information is available
# 2                   1  B check if sufficient information is available
# 3                   1                                B register claim
# 4                   1                                B register claim
# ..                ...                                             ...
# 4                3512                                S register claim
# 5                3512                   determine likelihood of claim
# 6                3512                   determine likelihood of claim
# 7                3512                                             end
# 8                3512                                             end
#
#    lifecycle:transition            time:timestamp call centre  \
# 0              complete 1970-01-01 00:00:00+00:00    Brisbane
# 1                 start 1970-01-01 00:00:00+00:00         NaN
# 2              complete 1970-01-01 00:00:41+00:00         NaN
# 3                 start 1970-01-01 00:00:41+00:00         NaN
# 4              complete 1970-01-01 00:12:59+00:00         NaN
# ..                  ...                       ...         ...
# 4              complete 1970-01-01 02:39:31+00:00         NaN
# 5                 start 1970-01-01 06:56:04+00:00         NaN
# 6              complete 1970-01-01 06:56:35+00:00         NaN
# 7                 start 1970-01-01 06:56:35+00:00         NaN
# 8              complete 1970-01-01 06:56:35+00:00         NaN
#
#                   org:resource  location duration     outcome  \
# 0                     customer       NaN      NaN         NaN
# 1   Call Centre Agent Brisbane  Brisbane      NaN         NaN
# 2   Call Centre Agent Brisbane  Brisbane      NaN         NaN
# 3   Call Centre Agent Brisbane       NaN      NaN         NaN
# 4   Call Centre Agent Brisbane       NaN      NaN         NaN
# ..                         ...       ...      ...         ...
# 4     Call Centre Agent Sydney       NaN      NaN         NaN
# 5               Claims handler       NaN      NaN         NaN
# 6               Claims handler       NaN      NaN         NaN
# 7               Claims handler       NaN    17306  not liable
# 8               Claims handler       NaN    17306  not liable
#
#               case:description
# 0   Simulated process instance
# 1   Simulated process instance
# 2   Simulated process instance
# 3   Simulated process instance
# 4   Simulated process instance
# ..                         ...
# 4   Simulated process instance
# 5   Simulated process instance
# 6   Simulated process instance
# 7   Simulated process instance
# 8   Simulated process instance
#
# [46138 rows x 10 columns]

# %%
generator.event_attributes_info_df()
# Out:
#                    name                     level            xes_type  \
# 0           call centre  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
# 1          org:resource  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 2        time:timestamp                      None    XesTypeEnum.DATE
# 3  lifecycle:transition                      None  XesTypeEnum.STRING
# 4          concept:name                      None  XesTypeEnum.STRING
# 5              location  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
# 6              duration  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
# 7               outcome  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
#
#    presence numeralicity is_trace_identifier
# 0  0.076119         None               False
# 1  1.000000         None               False
# 2       NaN         None                None
# 3       NaN         None                None
# 4       NaN         None                None
# 5  0.152239         None               False
# 6  0.152239         None               False
# 7  0.152239         None               False

# %%
score__simple = {
    "org:resource": evaluate_attribute_accuracy_score("org:resource", log, generator),
}

score__simple
# Out:
# {'org:resource': np.float64(0.9756383155689455)}

# %% [markdown]
# # photo_copier

# %%
file_path = maxes.data.load_files.get_path__photo_copier()

loader, log, generator = prepare(file_path)
log.df
# Out:
#   start;    Loading XML
#   complete;    Loading XML
#   start;    Removing namespaces from XML file
#   complete;    Removing namespaces from XML file
#   start;    Collecting XML traces
#   complete;    Collecting XML traces
#   start;    Collecting XML events
#   complete;    Collecting XML events
#   start;    Validating
#   complete;    Validating
#   start;    Gathering meta data
#   complete;    Gathering meta data
#   start;    Fitting models for traces beginning timestamps
#   complete;    Fitting models for traces beginning timestamps
#   start;    Analysing sequence graph
#   complete;    Analysing sequence graph
#   start;    Fitting graph traverser
#   complete;    Fitting graph traverser
#   start;    Fittig models for time:timestamp attribute
#   complete;    Fittig models for time:timestamp attribute
#   start;    Collecting stats
#   complete;    Collecting stats
#   start;    Collecting attributes info
#   complete;    Collecting attributes info
#   start;    Fitting presence models
#   complete;    Fitting presence models
#   start;    Fitting trace-level attributes models
#   complete;    Fitting trace-level attributes models
#   start;    Fitting event-level attributes models
#   complete;    Fitting event-level attributes models
#      case:concept:name        concept:name lifecycle:transition  \
# 0                    1                 Job                start
# 1                    1        Remote Print             complete
# 2                    1  Read Print Options             complete
# 3                    1       Rasterization                start
# 4                    1      Interpretation                start
# ..                 ...                 ...                  ...
# 120                100         Compression             complete
# 121                100         Store Image             complete
# 122                100      Transfer Image             complete
# 123                100           Send SMTP             complete
# 124                100                 Job             complete
#
#                time:timestamp org:resource            case:description  \
# 0   1970-01-01 00:00:00+00:00         PRN1  Simulated process instance
# 1   1970-01-01 00:15:00+00:00         PRN1  Simulated process instance
# 2   1970-01-01 00:26:00+00:00         PRN1  Simulated process instance
# 3   1970-01-01 00:38:00+00:00         PRN1  Simulated process instance
# 4   1970-01-01 00:51:00+00:00         PRN1  Simulated process instance
# ..                        ...          ...                         ...
# 120 1970-12-18 18:46:00+00:00         PRN1  Simulated process instance
# 121 1970-12-18 18:53:00+00:00         PRN1  Simulated process instance
# 122 1970-12-18 19:11:00+00:00         PRN1  Simulated process instance
# 123 1970-12-18 19:18:00+00:00         PRN1  Simulated process instance
# 124 1970-12-18 19:36:00+00:00         PRN1  Simulated process instance
#
#     case:Class
# 0        Print
# 1        Print
# 2        Print
# 3        Print
# 4        Print
# ..         ...
# 120  Copy/Scan
# 121  Copy/Scan
# 122  Copy/Scan
# 123  Copy/Scan
# 124  Copy/Scan
#
# [40995 rows x 7 columns]

# %%
generator.event_attributes_info_df()
# Out:
#                    name                     level            xes_type  \
# 0          org:resource  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
# 1        time:timestamp                      None    XesTypeEnum.DATE
# 2          concept:name                      None  XesTypeEnum.STRING
# 3  lifecycle:transition                      None  XesTypeEnum.STRING
#
#    presence numeralicity is_trace_identifier
# 0       1.0         None               False
# 1       NaN         None                None
# 2       NaN         None                None
# 3       NaN         None                None

# %% [markdown]
# ~ no attributes ~

# %% [markdown]
# # activitylog_uci_detailed_labour

# %%
file_path = (
    maxes.data.load_files.get_path__daily_living_activities__activitylog_uci_detailed_labour()
)

loader, log, generator = prepare(file_path)
log.df
# Out:
#   start;    Loading XML
#   complete;    Loading XML
#   start;    Removing namespaces from XML file
#   complete;    Removing namespaces from XML file
#   start;    Collecting XML traces
#   complete;    Collecting XML traces
#   start;    Collecting XML events
#   complete;    Collecting XML events
#   start;    Validating
#   complete;    Validating
#   start;    Gathering meta data
#   complete;    Gathering meta data
#   start;    Fitting models for traces beginning timestamps
#   complete;    Fitting models for traces beginning timestamps
#   start;    Analysing sequence graph
#   complete;    Analysing sequence graph
#   start;    Fitting graph traverser
#   complete;    Fitting graph traverser
#   start;    Fittig models for time:timestamp attribute
#   complete;    Fittig models for time:timestamp attribute
#   start;    Collecting stats
#   complete;    Collecting stats
#   start;    Collecting attributes info
#   complete;    Collecting attributes info
#   start;    Fitting presence models
#   complete;    Fitting presence models
#   start;    Fitting trace-level attributes models
#   complete;    Fitting trace-level attributes models
#   start;    Fitting event-level attributes models
#     start;      Fitting model for Column_4
#       start;      Fitting transformers for Column_4
#       complete;      Fitting transformers for Column_4
#       start;      Fitting prediction model for Column_4
#       complete;      Fitting prediction model for Column_4
#     complete;      Fitting model for Column_4
#   complete;    Fitting event-level attributes models
#     case:concept:name concept:name lifecycle:transition  \
# 0                   1        Start                start
# 1                   1        Start             complete
# 2                   1      washing                start
# 3                   1      washing             complete
# 4                   1   watchingtv                start
# ..                ...          ...                  ...
# 37                 25      washing             complete
# 38                 25   watchingtv                start
# 39                 25   watchingtv             complete
# 40                 25          End                start
# 41                 25          End             complete
#
#               time:timestamp    Column_4    case:creator
# 0  2012-11-11 23:48:38+00:00       Start  Fluxicon Disco
# 1  2012-11-11 23:48:38+00:00       Start  Fluxicon Disco
# 2  2012-11-11 23:48:38+00:00     washing  Fluxicon Disco
# 3  2012-11-11 23:50:12+00:00     washing  Fluxicon Disco
# 4  2012-11-11 23:50:29+00:00  watchingtv  Fluxicon Disco
# ..                       ...         ...             ...
# 37 2011-12-09 20:04:50+00:00     washing  Fluxicon Disco
# 38 2011-12-09 20:04:59+00:00  watchingtv  Fluxicon Disco
# 39 2011-12-09 23:16:21+00:00  watchingtv  Fluxicon Disco
# 40 2011-12-09 23:16:21+00:00         End  Fluxicon Disco
# 41 2011-12-09 23:16:21+00:00         End  Fluxicon Disco
#
# [1392 rows x 6 columns]

# %%
generator.event_attributes_info_df()
# Out:
#                    name                     level            xes_type  \
# 0          concept:name                      None  XesTypeEnum.STRING
# 1  lifecycle:transition                      None  XesTypeEnum.STRING
# 2        time:timestamp                      None    XesTypeEnum.DATE
# 3              Column_4  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
#
#    presence numeralicity is_trace_identifier
# 0       NaN         None                None
# 1       NaN         None                None
# 2       NaN         None                None
# 3       1.0         None               False

# %%
score__activitylog_uci_detailed_labour = {
    "Column_4": evaluate_attribute_accuracy_score("Column_4", log, generator),
}

score__activitylog_uci_detailed_labour
# Out:
# {'Column_4': np.float64(0.9784482091745959)}

# %% [markdown]
# # ccc19

# %%
file_path = maxes.data.load_files.get_path__ccc19__data()

loader, log, generator = prepare(file_path)
log.df
# Out:
#   start;    Loading XML
#   complete;    Loading XML
#   start;    Removing namespaces from XML file
#   complete;    Removing namespaces from XML file
#   start;    Collecting XML traces
#   complete;    Collecting XML traces
#   start;    Collecting XML events
#   complete;    Collecting XML events
#   start;    Validating
#   complete;    Validating
#   start;    Gathering meta data
#   complete;    Gathering meta data
#   start;    Fitting models for traces beginning timestamps
#   complete;    Fitting models for traces beginning timestamps
#   start;    Analysing sequence graph
#   complete;    Analysing sequence graph
#   start;    Fitting graph traverser
#   complete;    Fitting graph traverser
#   start;    Fittig models for time:timestamp attribute
#   complete;    Fittig models for time:timestamp attribute
#   start;    Collecting stats
#   complete;    Collecting stats
#   start;    Collecting attributes info
#   complete;    Collecting attributes info
#   start;    Fitting presence models
#   complete;    Fitting presence models
#   start;    Fitting trace-level attributes models
#   complete;    Fitting trace-level attributes models
#   start;    Fitting event-level attributes models
#     start;      Fitting model for EVENTID
#       start;      Fitting transformers for EVENTID
#       complete;      Fitting transformers for EVENTID
#       start;      Fitting prediction model for EVENTID
#       complete;      Fitting prediction model for EVENTID
#     complete;      Fitting model for EVENTID
#     start;      Fitting model for ACTIVITY
#       start;      Fitting transformers for ACTIVITY
#       complete;      Fitting transformers for ACTIVITY
#       start;      Fitting prediction model for ACTIVITY
#       complete;      Fitting prediction model for ACTIVITY
#     complete;      Fitting model for ACTIVITY
#     start;      Fitting model for STAGE
#       start;      Fitting transformers for STAGE
#       complete;      Fitting transformers for STAGE
#       start;      Fitting prediction model for STAGE
#       complete;      Fitting prediction model for STAGE
#     complete;      Fitting model for STAGE
#     start;      Fitting model for VIDEOSTART
#       start;      Fitting transformers for VIDEOSTART
#       complete;      Fitting transformers for VIDEOSTART
#       start;      Fitting prediction model for VIDEOSTART
#       complete;      Fitting prediction model for VIDEOSTART
#     complete;      Fitting model for VIDEOSTART
#     start;      Fitting model for VIDEOEND
#       start;      Fitting transformers for VIDEOEND
#       complete;      Fitting transformers for VIDEOEND
#       start;      Fitting prediction model for VIDEOEND
#       complete;      Fitting prediction model for VIDEOEND
#     complete;      Fitting model for VIDEOEND
#   complete;    Fitting event-level attributes models
#     case:concept:name              concept:name lifecycle:transition  \
# 0                   1              Hand washing                start
# 1                   1              Hand washing             complete
# 2                   1  Ultrasound configuration                start
# 3                   1  Ultrasound configuration             complete
# 4                   1   Anatomic identification                start
# ..                ...                       ...                  ...
# 67                 20          Remove guidewire             complete
# 68                 20     Check flow and reflow                start
# 69                 20     Check flow and reflow             complete
# 70                 20   Check catheter position                start
# 71                 20   Check catheter position             complete
#
#               time:timestamp org:resource RESOURCE ROUND        EVENTID  \
# 0  2018-10-11 12:00:00+00:00      R_13_1C  R_13_1C   Pre  1539301115461
# 1  2018-10-11 12:01:00+00:00      R_13_1C  R_13_1C   Pre  1539301115461
# 2  2018-10-11 12:01:00+00:00      R_13_1C  R_13_1C   Pre  1539301145312
# 3  2018-10-11 12:02:00+00:00      R_13_1C  R_13_1C   Pre  1539301145312
# 4  2018-10-11 12:02:00+00:00      R_13_1C  R_13_1C   Pre  1539301204591
# ..                       ...          ...      ...   ...            ...
# 67 2018-10-17 16:16:00+00:00      R_48_2D  R_48_2D   Pre  1539832239808
# 68 2018-10-17 16:16:00+00:00      R_48_2D  R_48_2D   Pre  1539832243182
# 69 2018-10-17 16:16:00+00:00      R_48_2D  R_48_2D   Pre  1539832243182
# 70 2018-10-17 16:16:00+00:00      R_48_2D  R_48_2D   Pre  1539832264783
# 71 2018-10-17 16:16:00+00:00      R_48_2D  R_48_2D   Pre  1539832264783
#
#                     ACTIVITY                             STAGE VIDEOSTART  \
# 0               Hand washing  Operator and Patient Preparation         55
# 1               Hand washing  Operator and Patient Preparation         55
# 2   Ultrasound configuration            Ultrasound Preparation         84
# 3   Ultrasound configuration            Ultrasound Preparation         84
# 4    Anatomic identification                 Locate Structures        143
# ..                       ...                               ...        ...
# 67          Remove guidewire                  Install Catheter        963
# 68     Check flow and reflow                  Install Catheter        968
# 69     Check flow and reflow                  Install Catheter        968
# 70   Check catheter position                  Install Catheter       1001
# 71   Check catheter position                  Install Catheter       1001
#
#    VIDEOEND case:variant  case:variant-index    case:creator
# 0        67    Variant 1                   1  Fluxicon Disco
# 1        67    Variant 1                   1  Fluxicon Disco
# 2       137    Variant 1                   1  Fluxicon Disco
# 3       137    Variant 1                   1  Fluxicon Disco
# 4       143    Variant 1                   1  Fluxicon Disco
# ..      ...          ...                 ...             ...
# 67      966   Variant 20                  20  Fluxicon Disco
# 68      994   Variant 20                  20  Fluxicon Disco
# 69      994   Variant 20                  20  Fluxicon Disco
# 70     1001   Variant 20                  20  Fluxicon Disco
# 71     1001   Variant 20                  20  Fluxicon Disco
#
# [1394 rows x 15 columns]

# %%
generator.event_attributes_info_df()
# Out:
#                     name                     level            xes_type  \
# 0           concept:name                      None  XesTypeEnum.STRING
# 1   lifecycle:transition                      None  XesTypeEnum.STRING
# 2           org:resource  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
# 3         time:timestamp                      None    XesTypeEnum.DATE
# 4               RESOURCE  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
# 5                  ROUND  AttributeLevelEnum.TRACE  XesTypeEnum.STRING
# 6                EVENTID  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 7               ACTIVITY  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 8                  STAGE  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 9             VIDEOSTART  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
# 10              VIDEOEND  AttributeLevelEnum.EVENT  XesTypeEnum.STRING
#
#     presence numeralicity is_trace_identifier
# 0        NaN         None                None
# 1        NaN         None                None
# 2        1.0         None               False
# 3        NaN         None                None
# 4        1.0         None               False
# 5        1.0         None               False
# 6        1.0         None               False
# 7        1.0         None               False
# 8        1.0         None               False
# 9        1.0         None               False
# 10       1.0         None               False

# %%
score__ccc19 = {
    "EVENTID": evaluate_attribute_accuracy_score("EVENTID", log, generator),
    "ACTIVITY": evaluate_attribute_accuracy_score("ACTIVITY", log, generator),
    "STAGE": evaluate_attribute_accuracy_score("STAGE", log, generator),
    "VIDEOSTART": evaluate_attribute_accuracy_score("VIDEOSTART", log, generator),
    "VIDEOEND": evaluate_attribute_accuracy_score("VIDEOEND", log, generator),
}

score__ccc19
# Out:
# {'EVENTID': np.float64(0.0),
#  'ACTIVITY': np.float64(0.5495397230602614),
#  'STAGE': np.float64(1.0),
#  'VIDEOSTART': np.float64(0.0),
#  'VIDEOEND': np.float64(0.008607307702225318)}

# %% [markdown]
# # all

# %%
print()
print("simple")
print(score__simple)

print()
print("activitylog_uci_detailed_labour")
print(score__activitylog_uci_detailed_labour)

print()
print("bpic2020")
print(score__bpic2020)

print()
print("ccc19")
print(score__ccc19)

print()
print("env_permit_application_process")
print(score__env_permit_application_process)
# Out:
# simple
# {'org:resource': np.float64(0.9756383155689455)}
#
# activitylog_uci_detailed_labour
# {'Column_4': np.float64(0.9784482091745959)}
#
# bpic2020
# {'org:resource': np.float64(1.0), 'org:role': np.float64(0.9999184708756506)}
#
# ccc19
# {'EVENTID': np.float64(0.0), 'ACTIVITY': np.float64(0.5495397230602614), 'STAGE': np.float64(1.0), 'VIDEOSTART': np.float64(0.0), 'VIDEOEND': np.float64(0.008607307702225318)}
#
# env_permit_application_process
# {'org:resource': np.float64(0.1449233759437841), 'org:group': np.float64(0.857410276798032)}

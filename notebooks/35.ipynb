# %%
# %load_ext autoreload
import datetime
# import ete3
import itertools
import json
import logging
import math
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import os
import pandas as pd
import typing
# import re
import xml.etree.ElementTree as ET
# import xml.dom.minidom
# import xmlschema

# %%
# %autoreload
from maxes.xes_loader2 import XesLoader, XesLog, XesTrace, XesEvent, XES_STRING, XES_INT, XES_DATE
# from maxes.xes_file import XesFile
# from maxes.analyze_xes import AnalyzeXes
# import maxes.analyze_sequence
# import maxes.serialization.serialize
# import maxes.graphs
import maxes.metrics.mean_levenstein_distance
import maxes.notebooks.utils
import maxes.utils

# %%
maxes.notebooks.utils.init_notebook() # RUN ONLY ONCE
# Out:
# Loading config from: C:\vt\md\maxes\maxes\config.local.yml
# Config:
# {'project_directory_path': '/vt/md/maxes/maxes', 'data_directory_path': '/vt/md/maxes/maxes/data'}

# %%
ccc19_processed_path = os.path.join(maxes.notebooks.utils.get_project_path(), "output/data_processed/ccc19.xes")
ccc19_generated_path = os.path.join(maxes.notebooks.utils.get_project_path(), "output/data_generated/ccc19.xes")

ccc19_processed = maxes.notebooks.utils.load_xes(ccc19_processed_path)
ccc19_processed

ccc19_generated = maxes.notebooks.utils.generate_log(ccc19_processed)
maxes.notebooks.utils.write_xes_to_file(ccc19_generated, skeleton_log=ccc19_processed, destination_file_path=ccc19_generated_path)

# %%
eleven_original_path = "C:\\vt\\md\\maxes\\maxes\\data\\other\\11.xes"
eleven_generated_path = "C:\\vt\\md\\maxes\\maxes\\output\\data_generated\\11.xes"

eleven_processed = maxes.notebooks.utils.load_xes(eleven_original_path)
eleven_processed

eleven_generated = maxes.notebooks.utils.generate_log(eleven_processed)
maxes.notebooks.utils.write_xes_to_file(eleven_generated, skeleton_log=eleven_processed, destination_file_path=eleven_generated_path)

# %%
def get_attributes_weights1(original_log: XesLog) -> dict[str, float]:
    # All attributes are equally important

    event_attributes_count = len(original_log.event_attribute_type_map)
    attributes_weights = {attribute_name: 1.0 / float(event_attributes_count)
                          for attribute_name in original_log.event_attribute_type_map.keys()}

    return attributes_weights

def get_attributes_weights2(original_log: XesLog) -> dict[str, float]:
    # String attributes are less important

    attributes_weights: dict[str, float] = {}

    for attribute_name, attribute_type in original_log.event_attribute_type_map.items():
        weight = 1.0

        if attribute_type == 'str':
            weight = 0.2

        attributes_weights[attribute_name] = weight

    return maxes.utils.normalize(attributes_weights)

def calculate_attributes_range_lengths(event_attribute_type_map: dict[str, str], original_trace: XesTrace) -> dict[str, float]:
    attributes_range_lengths: dict[str, float] = {}

    for attribute_name, attribute_type in event_attribute_type_map.items():
        range_length = None

        if attribute_type == XES_INT:
            series = original_trace.df[attribute_name]
            range_length = series.max() - series.min()

        if attribute_type == XES_DATE:
            series = original_trace.df[attribute_name]
            range_length = (series.max() - series.min()).seconds

        if range_length != None:
            attributes_range_lengths[attribute_name] = range_length

    return attributes_range_lengths

def calculate_event_error(
        original_event: XesEvent,
        generated_event: XesEvent,

        event_attribute_type_map: dict[str, str],
        attributes_range_lengths: dict[str, float],
        attributes_weights: dict[str, float]
        ) -> float:
    event_error = 0

    for attribute_name, attribute_type in event_attribute_type_map.items():
        attribute_error = 0

        if attribute_type == XES_STRING:
            if original_event[attribute_name] != generated_event[attribute_name]:
                attribute_error = 1

        if attribute_type == XES_INT:
            delta = original_event[attribute_name] - generated_event[attribute_name]
            scaled_delta = delta / attributes_range_lengths[attribute_name]
            # attribute_error = scaled_delta ** 2
            attribute_error = scaled_delta

        if attribute_type == XES_DATE:
            delta = original_event[attribute_name].second - generated_event[attribute_name].second
            scaled_delta = delta / attributes_range_lengths[attribute_name]
            # attribute_error = scaled_delta ** 2
            attribute_error = scaled_delta

        print(f"attribute_name: {attribute_name}, attribute_error: {attribute_error}")

        # TODO: Other types

        weighted_attribute_error = attribute_error * attributes_weights[attribute_name]
        event_error += weighted_attribute_error

    return event_error

def calculate_trace_error(
        original_trace: XesTrace,
        generated_trace: XesTrace,

        event_attribute_type_map: dict[str, str],
        attributes_weights: dict[str, float],
        ) -> float:
    attributes_range_lengths = calculate_attributes_range_lengths(event_attribute_type_map, original_trace)

    accumulated_error = 0

    for original_event in original_trace.events:
        # TODO: Find best event by lowest error

        generated_events_candidates = [
            {
                "event": event,
                "error": calculate_event_error(
                    original_event=original_event,
                    generated_event=event,
                    event_attribute_type_map=event_attribute_type_map,
                    attributes_range_lengths=attributes_range_lengths,
                    attributes_weights=attributes_weights
                )
            }
            for event in generated_trace.events
            if event.concept_name == original_event.concept_name
        ]

        if len(generated_events_candidates) == 0:
            continue

        suitable_event_with_error = min(generated_events_candidates, key=lambda item: item["error"])
        event_error = suitable_event_with_error["error"]

        accumulated_error += event_error

    mean_error = accumulated_error / float(len(original_trace.events))
    return mean_error

def calculate_log_error(
        original_log: XesLog,
        traces_pairs: list[tuple[XesTrace, XesTrace]],
        attribute_weights: dict[str, float]
        ) -> float:
    accumulated_error = 0

    for original_trace, generated_trace in traces_pairs:
        trace_error = calculate_trace_error(
            original_trace,
            generated_trace,
            event_attribute_type_map=original_log.event_attribute_type_map,
            attributes_weights=attribute_weights
        )

        accumulated_error += trace_error

    mean_log_error = accumulated_error / float(len(original_log.traces))

    return mean_log_error

# %%
trace_mappings = maxes.metrics.mean_levenstein_distance.mean_levenstein_distance(ccc19_processed, ccc19_generated)
trace_mappings

trace_pairs = [(trace_pair.original_sequence.trace, trace_pair.generated_sequence.trace) for trace_pair in trace_mappings]
attribute_weights = get_attributes_weights1(ccc19_processed)

[(trace_pair.original_sequence.index, trace_pair.generated_sequence.index) for trace_pair in trace_mappings]
# Out:
# [(9, 1),
#  (19, 8),
#  (5, 11),
#  (2, 2),
#  (6, 0),
#  (3, 12),
#  (4, 4),
#  (17, 9),
#  (10, 14),
#  (12, 10),
#  (1, 6),
#  (16, 19),
#  (7, 7),
#  (11, 16),
#  (14, 17),
#  (15, 5),
#  (0, 13),
#  (8, 3),
#  (18, 15),
#  (13, 18)]

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)

ccc19_processed.traces[9].df
# Out:
#                   concept:name lifecycle:transition org:resource  \
# 0           Prepare implements                start      R_45_2A
# 1           Prepare implements             complete      R_45_2A
# 2       Get in sterile clothes                start      R_45_2A
# 3       Get in sterile clothes             complete      R_45_2A
# 4                 Hand washing                start      R_45_2A
# 5                 Hand washing             complete      R_45_2A
# 6       Get in sterile clothes                start      R_45_2A
# 7       Get in sterile clothes             complete      R_45_2A
# 8           Prepare implements                start      R_45_2A
# 9           Prepare implements             complete      R_45_2A
# 10         Clean puncture area                start      R_45_2A
# 11         Clean puncture area             complete      R_45_2A
# 12          Drap puncture area                start      R_45_2A
# 13          Drap puncture area             complete      R_45_2A
# 14          Prepare implements                start      R_45_2A
# 15          Prepare implements             complete      R_45_2A
# 16    Ultrasound configuration                start      R_45_2A
# 17    Ultrasound configuration             complete      R_45_2A
# 18                 Cover probe                start      R_45_2A
# 19                Gel in probe                start      R_45_2A
# 20                Gel in probe             complete      R_45_2A
# 21                 Cover probe             complete      R_45_2A
# 22             Put sterile gel                start      R_45_2A
# 23             Put sterile gel             complete      R_45_2A
# 24              Position probe                start      R_45_2A
# 25              Position probe             complete      R_45_2A
# 26    Ultrasound configuration                start      R_45_2A
# 27    Ultrasound configuration             complete      R_45_2A
# 28     Anatomic identification                start      R_45_2A
# 29     Anatomic identification             complete      R_45_2A
# 30  Compression identification                start      R_45_2A
# 31  Compression identification             complete      R_45_2A
# 32                 Anesthetize                start      R_45_2A
# 33                 Anesthetize             complete      R_45_2A
# 34                    Puncture                start      R_45_2A
# 35                    Puncture             complete      R_45_2A
# 36                Blood return                start      R_45_2A
# 37                Blood return             complete      R_45_2A
# 38                  Drop probe                start      R_45_2A
# 39                  Drop probe             complete      R_45_2A
# 40              Remove syringe                start      R_45_2A
# 41              Remove syringe             complete      R_45_2A
# 42           Guidewire install                start      R_45_2A
# 43           Guidewire install             complete      R_45_2A
# 44               Remove trocar                start      R_45_2A
# 45               Remove trocar             complete      R_45_2A
# 46    Check wire in short axis                start      R_45_2A
# 47    Check wire in short axis             complete      R_45_2A
# 48     Check wire in long axis                start      R_45_2A
# 49     Check wire in long axis             complete      R_45_2A
# 50       Wire in good position                start      R_45_2A
# 51       Wire in good position             complete      R_45_2A
# 52               Widen pathway                start      R_45_2A
# 53               Widen pathway             complete      R_45_2A
# 54            Advance catheter                start      R_45_2A
# 55            Advance catheter             complete      R_45_2A
# 56            Remove guidewire                start      R_45_2A
# 57            Remove guidewire             complete      R_45_2A
# 58       Check flow and reflow                start      R_45_2A
# 59       Check flow and reflow             complete      R_45_2A
# 60     Check catheter position                start      R_45_2A
# 61     Check catheter position             complete      R_45_2A
#
#               time:timestamp RESOURCE ROUND                    ACTIVITY  \
# 0  2019-01-19 14:00:00+00:00  R_45_2A  Post          Prepare implements
# 1  2019-01-19 14:01:00+00:00  R_45_2A  Post          Prepare implements
# 2  2019-01-19 14:01:00+00:00  R_45_2A  Post      Get in sterile clothes
# 3  2019-01-19 14:01:00+00:00  R_45_2A  Post      Get in sterile clothes
# 4  2019-01-19 14:01:00+00:00  R_45_2A  Post                Hand washing
# 5  2019-01-19 14:02:00+00:00  R_45_2A  Post                Hand washing
# 6  2019-01-19 14:02:00+00:00  R_45_2A  Post      Get in sterile clothes
# 7  2019-01-19 14:04:00+00:00  R_45_2A  Post      Get in sterile clothes
# 8  2019-01-19 14:04:00+00:00  R_45_2A  Post          Prepare implements
# 9  2019-01-19 14:04:00+00:00  R_45_2A  Post          Prepare implements
# 10 2019-01-19 14:04:00+00:00  R_45_2A  Post         Clean puncture area
# 11 2019-01-19 14:05:00+00:00  R_45_2A  Post         Clean puncture area
# 12 2019-01-19 14:05:00+00:00  R_45_2A  Post          Drap puncture area
# 13 2019-01-19 14:05:00+00:00  R_45_2A  Post          Drap puncture area
# 14 2019-01-19 14:05:00+00:00  R_45_2A  Post          Prepare implements
# 15 2019-01-19 14:07:00+00:00  R_45_2A  Post          Prepare implements
# 16 2019-01-19 14:07:00+00:00  R_45_2A  Post    Ultrasound configuration
# 17 2019-01-19 14:07:00+00:00  R_45_2A  Post    Ultrasound configuration
# 18 2019-01-19 14:07:00+00:00  R_45_2A  Post                 Cover probe
# 19 2019-01-19 14:08:00+00:00  R_45_2A  Post                Gel in probe
# 20 2019-01-19 14:08:00+00:00  R_45_2A  Post                Gel in probe
# 21 2019-01-19 14:10:00+00:00  R_45_2A  Post                 Cover probe
# 22 2019-01-19 14:10:00+00:00  R_45_2A  Post             Put sterile gel
# 23 2019-01-19 14:10:00+00:00  R_45_2A  Post             Put sterile gel
# 24 2019-01-19 14:10:00+00:00  R_45_2A  Post              Position probe
# 25 2019-01-19 14:10:00+00:00  R_45_2A  Post              Position probe
# 26 2019-01-19 14:11:00+00:00  R_45_2A  Post    Ultrasound configuration
# 27 2019-01-19 14:11:00+00:00  R_45_2A  Post    Ultrasound configuration
# 28 2019-01-19 14:11:00+00:00  R_45_2A  Post     Anatomic identification
# 29 2019-01-19 14:11:00+00:00  R_45_2A  Post     Anatomic identification
# 30 2019-01-19 14:11:00+00:00  R_45_2A  Post  Compression identification
# 31 2019-01-19 14:11:00+00:00  R_45_2A  Post  Compression identification
# 32 2019-01-19 14:12:00+00:00  R_45_2A  Post                 Anesthetize
# 33 2019-01-19 14:12:00+00:00  R_45_2A  Post                 Anesthetize
# 34 2019-01-19 14:12:00+00:00  R_45_2A  Post                    Puncture
# 35 2019-01-19 14:13:00+00:00  R_45_2A  Post                    Puncture
# 36 2019-01-19 14:13:00+00:00  R_45_2A  Post                Blood return
# 37 2019-01-19 14:13:00+00:00  R_45_2A  Post                Blood return
# 38 2019-01-19 14:13:00+00:00  R_45_2A  Post                  Drop probe
# 39 2019-01-19 14:13:00+00:00  R_45_2A  Post                  Drop probe
# 40 2019-01-19 14:13:00+00:00  R_45_2A  Post              Remove syringe
# 41 2019-01-19 14:13:00+00:00  R_45_2A  Post              Remove syringe
# 42 2019-01-19 14:13:00+00:00  R_45_2A  Post           Guidewire install
# 43 2019-01-19 14:14:00+00:00  R_45_2A  Post           Guidewire install
# 44 2019-01-19 14:14:00+00:00  R_45_2A  Post               Remove trocar
# 45 2019-01-19 14:15:00+00:00  R_45_2A  Post               Remove trocar
# 46 2019-01-19 14:15:00+00:00  R_45_2A  Post    Check wire in short axis
# 47 2019-01-19 14:15:00+00:00  R_45_2A  Post    Check wire in short axis
# 48 2019-01-19 14:15:00+00:00  R_45_2A  Post     Check wire in long axis
# 49 2019-01-19 14:15:00+00:00  R_45_2A  Post     Check wire in long axis
# 50 2019-01-19 14:15:00+00:00  R_45_2A  Post       Wire in good position
# 51 2019-01-19 14:15:00+00:00  R_45_2A  Post       Wire in good position
# 52 2019-01-19 14:15:00+00:00  R_45_2A  Post               Widen pathway
# 53 2019-01-19 14:15:00+00:00  R_45_2A  Post               Widen pathway
# 54 2019-01-19 14:15:00+00:00  R_45_2A  Post            Advance catheter
# 55 2019-01-19 14:16:00+00:00  R_45_2A  Post            Advance catheter
# 56 2019-01-19 14:17:00+00:00  R_45_2A  Post            Remove guidewire
# 57 2019-01-19 14:17:00+00:00  R_45_2A  Post            Remove guidewire
# 58 2019-01-19 14:18:00+00:00  R_45_2A  Post       Check flow and reflow
# 59 2019-01-19 14:18:00+00:00  R_45_2A  Post       Check flow and reflow
# 60 2019-01-19 14:18:00+00:00  R_45_2A  Post     Check catheter position
# 61 2019-01-19 14:18:00+00:00  R_45_2A  Post     Check catheter position
#
#                                STAGE  VIDEOSTART  VIDEOEND
# 0   Operator and Patient Preparation          16        66
# 1   Operator and Patient Preparation          16        66
# 2   Operator and Patient Preparation          67       106
# 3   Operator and Patient Preparation          67       106
# 4   Operator and Patient Preparation         108       127
# 5   Operator and Patient Preparation         108       127
# 6   Operator and Patient Preparation         129       255
# 7   Operator and Patient Preparation         129       255
# 8   Operator and Patient Preparation         257       290
# 9   Operator and Patient Preparation         257       290
# 10  Operator and Patient Preparation         292       315
# 11  Operator and Patient Preparation         292       315
# 12  Operator and Patient Preparation         317       347
# 13  Operator and Patient Preparation         317       347
# 14  Operator and Patient Preparation         355       420
# 15  Operator and Patient Preparation         355       420
# 16            Ultrasound Preparation         424       471
# 17            Ultrasound Preparation         424       471
# 18            Ultrasound Preparation         476       610
# 19            Ultrasound Preparation         493       500
# 20            Ultrasound Preparation         493       500
# 21            Ultrasound Preparation         476       610
# 22            Ultrasound Preparation         612       621
# 23            Ultrasound Preparation         612       621
# 24            Ultrasound Preparation         649       649
# 25            Ultrasound Preparation         649       649
# 26            Ultrasound Preparation         663       691
# 27            Ultrasound Preparation         663       691
# 28                 Locate Structures         693       693
# 29                 Locate Structures         693       693
# 30                 Locate Structures         698       698
# 31                 Locate Structures         698       698
# 32                   Venous puncture         748       760
# 33                   Venous puncture         748       760
# 34                   Venous puncture         765       789
# 35                   Venous puncture         765       789
# 36                   Venous puncture         790       790
# 37                   Venous puncture         790       790
# 38                 Install Guidewire         792       792
# 39                 Install Guidewire         792       792
# 40                 Install Guidewire         800       810
# 41                 Install Guidewire         800       810
# 42                 Install Guidewire         815       887
# 43                 Install Guidewire         815       887
# 44                 Install Guidewire         895       901
# 45                 Install Guidewire         895       901
# 46                 Install Guidewire         903       910
# 47                 Install Guidewire         903       910
# 48                 Install Guidewire         912       915
# 49                 Install Guidewire         912       915
# 50                 Install Guidewire         916       916
# 51                 Install Guidewire         916       916
# 52                  Install Catheter         921       929
# 53                  Install Catheter         921       929
# 54                  Install Catheter         931      1019
# 55                  Install Catheter         931      1019
# 56                  Install Catheter        1021      1059
# 57                  Install Catheter        1021      1059
# 58                  Install Catheter        1080      1091
# 59                  Install Catheter        1080      1091
# 60                  Install Catheter        1093      1095
# 61                  Install Catheter        1093      1095

# %%
ccc19_generated.traces[1].df
# Out:
#                   concept:name lifecycle:transition  \
# 0       Get in sterile clothes                start
# 1       Get in sterile clothes             complete
# 2           Prepare implements             complete
# 3       Get in sterile clothes                start
# 4       Get in sterile clothes             complete
# 5                 Hand washing                start
# 6                 Hand washing             complete
# 7       Get in sterile clothes                start
# 8       Get in sterile clothes             complete
# 9           Prepare implements             complete
# 10          Drap puncture area                start
# 11          Drap puncture area             complete
# 12          Prepare implements                start
# 13          Prepare implements             complete
# 14      Get in sterile clothes                start
# 15      Get in sterile clothes             complete
# 16          Prepare implements                start
# 17          Prepare implements             complete
# 18    Ultrasound configuration                start
# 19    Ultrasound configuration             complete
# 20     Anatomic identification                start
# 21     Anatomic identification             complete
# 22  Compression identification                start
# 23  Compression identification             complete
# 24                    Puncture                start
# 25                    Puncture             complete
# 26                Blood return                start
# 27                Blood return             complete
# 28                  Drop probe                start
# 29                  Drop probe             complete
# 30              Remove syringe                start
# 31              Remove syringe             complete
# 32           Guidewire install                start
# 33           Guidewire install             complete
# 34               Remove trocar                start
# 35               Remove trocar             complete
# 36    Check wire in short axis                start
# 37    Check wire in short axis             complete
# 38     Check wire in long axis                start
# 39     Check wire in long axis             complete
# 40       Wire in good position                start
# 41       Wire in good position             complete
# 42     Check wire in long axis                start
# 43     Check wire in long axis             complete
# 44       Wire in good position                start
# 45       Wire in good position             complete
# 46     Check wire in long axis                start
# 47     Check wire in long axis             complete
# 48               Widen pathway                start
# 49               Widen pathway             complete
# 50            Advance catheter                start
# 51            Advance catheter             complete
#
#                      time:timestamp  VIDEOSTART  VIDEOEND org:resource  \
# 0  2019-01-16 13:59:59.228876+00:00        1202       436      R_14_1D
# 1  2019-01-16 14:01:59.168401+00:00        1838      1264      R_45_2A
# 2  2019-01-16 14:02:59.915067+00:00        1888       317      R_14_1D
# 3  2019-01-16 14:02:59.548655+00:00        1364       473      R_21_1F
# 4  2019-01-16 14:02:58.993454+00:00         683      1630      R_31_1G
# 5  2019-01-16 14:02:57.952583+00:00        1234      1153      R_46_2B
# 6  2019-01-16 14:04:57.586655+00:00         801      1204      R_32_1H
# 7  2019-01-16 14:04:59.103730+00:00        2010      1413      R_32_1H
# 8  2019-01-16 14:06:59.198321+00:00        2014      1768      R_14_1D
# 9  2019-01-16 14:07:57.966333+00:00        1912       633      R_47_2C
# 10 2019-01-16 14:07:56.322148+00:00         549      1984      R_13_1C
# 11 2019-01-16 14:07:56.620539+00:00        1904       425      R_46_2B
# 12 2019-01-16 14:07:55.176157+00:00        1927       243      R_14_1D
# 13 2019-01-16 14:08:55.220494+00:00         267       296      R_48_2D
# 14 2019-01-16 14:08:54.623842+00:00        1242       752      R_47_2C
# 15 2019-01-16 14:10:54.447325+00:00        1339        76      R_45_2A
# 16 2019-01-16 14:10:53.573171+00:00         996       872      R_32_1H
# 17 2019-01-16 14:10:54.384763+00:00         949       330      R_13_1C
# 18 2019-01-16 14:10:53.279123+00:00        1772      1025      R_48_2D
# 19 2019-01-16 14:11:53.662016+00:00        1843       173      R_45_2A
# 20 2019-01-16 14:11:54.643880+00:00        1086       355      R_21_1F
# 21 2019-01-16 14:11:55.642923+00:00         641      1277      R_45_2A
# 22 2019-01-16 14:11:57.677132+00:00        1342      1571      R_31_1G
# 23 2019-01-16 14:11:57.605430+00:00         384      1377      R_13_1C
# 24 2019-01-16 14:12:57.667879+00:00        1797       281      R_14_1D
# 25 2019-01-16 14:12:55.367403+00:00        1886      1395      R_33_1L
# 26 2019-01-16 14:12:56.941667+00:00         933       687      R_21_1F
# 27 2019-01-16 14:12:56.531733+00:00         492       942      R_13_1C
# 28 2019-01-16 14:12:56.494111+00:00         812       429      R_13_1C
# 29 2019-01-16 14:12:55.477273+00:00        1596      1936      R_48_2D
# 30 2019-01-16 14:12:55.426478+00:00        1547      1006      R_32_1H
# 31 2019-01-16 14:12:56.464215+00:00        1322      1539      R_32_1H
# 32 2019-01-16 14:12:57.650233+00:00        1106       252      R_47_2C
# 33 2019-01-16 14:13:57.616899+00:00         923      1515      R_31_1G
# 34 2019-01-16 14:13:57.504528+00:00         399       771      R_32_1H
# 35 2019-01-16 14:13:57.953682+00:00         313      1800      R_33_1L
# 36 2019-01-16 14:13:58.006942+00:00         668       666      R_21_1F
# 37 2019-01-16 14:13:57.235573+00:00          73        88      R_14_1D
# 38 2019-01-16 14:13:57.327743+00:00        1057       757      R_32_1H
# 39 2019-01-16 14:13:56.110362+00:00        1613      2072      R_33_1L
# 40 2019-01-16 14:13:54.262646+00:00         882       792      R_14_1D
# 41 2019-01-16 14:13:54.061074+00:00         387      1412      R_31_1G
# 42 2019-01-16 14:13:54.765532+00:00         111       701      R_33_1L
# 43 2019-01-16 14:13:53.770884+00:00        2000      1211      R_32_1H
# 44 2019-01-16 14:13:55.976919+00:00        2050       960      R_21_1F
# 45 2019-01-16 14:13:55.938110+00:00         412      1804      R_13_1C
# 46 2019-01-16 14:13:56.045000+00:00         981      1776      R_31_1G
# 47 2019-01-16 14:13:55.213214+00:00         730        55      R_31_1G
# 48 2019-01-16 14:14:56.196823+00:00         821      1353      R_45_2A
# 49 2019-01-16 14:15:56.000362+00:00        1889      1409      R_31_1G
# 50 2019-01-16 14:15:55.693170+00:00        1909      1988      R_21_1F
# 51 2019-01-16 14:16:55.427620+00:00        1322       886      R_31_1G
#
#    RESOURCE ROUND                    ACTIVITY  \
# 0   R_33_1L   Pre                  Drop probe
# 1   R_47_2C  Post          Prepare implements
# 2   R_13_1C  Post       Check flow and reflow
# 3   R_45_2A   Pre             Put sterile gel
# 4   R_47_2C   Pre                Blood return
# 5   R_13_1C   Pre  Compression identification
# 6   R_13_1C   Pre                Gel in probe
# 7   R_31_1G  Post              Position probe
# 8   R_33_1L  Post    Ultrasound configuration
# 9   R_33_1L  Post              Remove syringe
# 10  R_32_1H   Pre    Ultrasound configuration
# 11  R_46_2B  Post          Drap puncture area
# 12  R_32_1H   Pre  Compression identification
# 13  R_31_1G   Pre            Remove guidewire
# 14  R_21_1F   Pre         Clean puncture area
# 15  R_45_2A   Pre            Advance catheter
# 16  R_48_2D   Pre          Prepare implements
# 17  R_32_1H   Pre  Compression identification
# 18  R_33_1L   Pre          Prepare implements
# 19  R_21_1F   Pre              Position probe
# 20  R_31_1G   Pre     Anatomic identification
# 21  R_14_1D  Post  Compression identification
# 22  R_47_2C   Pre      Get in sterile clothes
# 23  R_48_2D  Post                Blood return
# 24  R_33_1L   Pre         Clean puncture area
# 25  R_48_2D   Pre             Put sterile gel
# 26  R_31_1G   Pre               Widen pathway
# 27  R_45_2A  Post    Check wire in short axis
# 28  R_45_2A   Pre      Get in sterile clothes
# 29  R_13_1C   Pre                Gel in probe
# 30  R_31_1G  Post                Hand washing
# 31  R_14_1D  Post    Check wire in short axis
# 32  R_48_2D  Post     Check catheter position
# 33  R_31_1G  Post    Ultrasound configuration
# 34  R_48_2D   Pre            Remove guidewire
# 35  R_32_1H  Post             Put sterile gel
# 36  R_47_2C  Post  Compression identification
# 37  R_13_1C  Post               Remove trocar
# 38  R_46_2B   Pre       Wire in good position
# 39  R_21_1F   Pre          Drap puncture area
# 40  R_13_1C  Post          Drap puncture area
# 41  R_46_2B  Post               Remove trocar
# 42  R_31_1G  Post               Widen pathway
# 43  R_48_2D   Pre     Anatomic identification
# 44  R_21_1F  Post            Advance catheter
# 45  R_21_1F  Post              Remove syringe
# 46  R_32_1H   Pre    Ultrasound configuration
# 47  R_21_1F  Post             Put sterile gel
# 48  R_46_2B   Pre            Advance catheter
# 49  R_21_1F  Post     Anatomic identification
# 50  R_13_1C   Pre  Compression identification
# 51  R_21_1F  Post           Guidewire install
#
#                                STAGE
# 0                    Venous puncture
# 1                  Install Guidewire
# 2                   Install Catheter
# 3             Ultrasound Preparation
# 4   Operator and Patient Preparation
# 5                    Venous puncture
# 6   Operator and Patient Preparation
# 7   Operator and Patient Preparation
# 8   Operator and Patient Preparation
# 9                  Locate Structures
# 10                  Install Catheter
# 11                   Venous puncture
# 12  Operator and Patient Preparation
# 13  Operator and Patient Preparation
# 14                  Install Catheter
# 15                  Install Catheter
# 16                   Venous puncture
# 17  Operator and Patient Preparation
# 18  Operator and Patient Preparation
# 19  Operator and Patient Preparation
# 20                 Locate Structures
# 21  Operator and Patient Preparation
# 22                 Install Guidewire
# 23                  Install Catheter
# 24  Operator and Patient Preparation
# 25                 Install Guidewire
# 26  Operator and Patient Preparation
# 27            Ultrasound Preparation
# 28                   Venous puncture
# 29                 Install Guidewire
# 30                   Venous puncture
# 31  Operator and Patient Preparation
# 32                 Install Guidewire
# 33            Ultrasound Preparation
# 34            Ultrasound Preparation
# 35                 Install Guidewire
# 36                 Install Guidewire
# 37            Ultrasound Preparation
# 38  Operator and Patient Preparation
# 39            Ultrasound Preparation
# 40                  Install Catheter
# 41                  Install Catheter
# 42                 Install Guidewire
# 43  Operator and Patient Preparation
# 44            Ultrasound Preparation
# 45                  Install Catheter
# 46                 Install Guidewire
# 47                   Venous puncture
# 48                 Install Guidewire
# 49                   Venous puncture
# 50  Operator and Patient Preparation
# 51                   Venous puncture

# %%
calculate_log_error(
    ccc19_generated,
    trace_pairs,
    attribute_weights=attribute_weights
)
# Out:
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 3.0212056082742995
# attribute_name: VIDEOEND, attribute_error: 0.05949996269505997
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 3.09916900086126
# attribute_name: VIDEOEND, attribute_error: 0.3036234902124114
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.148400462442098
# attribute_name: VIDEOEND, attribute_error: 0.029588011797805337
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.05431453132045151
# attribute_name: VIDEOEND, attribute_error: 0.049960286766379466
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.827981712673793
# attribute_name: VIDEOEND, attribute_error: 0.6135349877838127
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.750467485509889
# attribute_name: VIDEOEND, attribute_error: 0.06582291392192029
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 3.0212056082742995
# attribute_name: VIDEOEND, attribute_error: 0.05949996269505997
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 3.09916900086126
# attribute_name: VIDEOEND, attribute_error: 0.3036234902124114
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.148400462442098
# attribute_name: VIDEOEND, attribute_error: 0.029588011797805337
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.05431453132045151
# attribute_name: VIDEOEND, attribute_error: 0.049960286766379466
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.827981712673793
# attribute_name: VIDEOEND, attribute_error: 0.6135349877838127
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.750467485509889
# attribute_name: VIDEOEND, attribute_error: 0.06582291392192029
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.110606769897123
# attribute_name: VIDEOEND, attribute_error: 0.10284830300300045
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.703993951353919
# attribute_name: VIDEOEND, attribute_error: 1.2664451036557898
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.4502689388747068
# attribute_name: VIDEOEND, attribute_error: 0.12720417890882577
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002884087791495199
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.3271372644360128
# attribute_name: VIDEOEND, attribute_error: 2.1935078071211827
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.2547242115681216
# attribute_name: VIDEOEND, attribute_error: 1.6133196580034208
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.268138825738472
# attribute_name: VIDEOEND, attribute_error: 2.60874295574123
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.1902668180552431
# attribute_name: VIDEOEND, attribute_error: 0.39412527471074504
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.3948991705526803
# attribute_name: VIDEOEND, attribute_error: 0.0008499859752314086
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.110606769897123
# attribute_name: VIDEOEND, attribute_error: 0.10284830300300045
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.703993951353919
# attribute_name: VIDEOEND, attribute_error: 1.2664451036557898
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.4502689388747068
# attribute_name: VIDEOEND, attribute_error: 0.12720417890882577
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002884087791495199
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.3271372644360128
# attribute_name: VIDEOEND, attribute_error: 2.1935078071211827
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.2547242115681216
# attribute_name: VIDEOEND, attribute_error: 1.6133196580034208
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.268138825738472
# attribute_name: VIDEOEND, attribute_error: 2.60874295574123
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.1902668180552431
# attribute_name: VIDEOEND, attribute_error: 0.39412527471074504
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.3948991705526803
# attribute_name: VIDEOEND, attribute_error: 0.0008499859752314086
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.0930634547459368
# attribute_name: VIDEOEND, attribute_error: 0.9941775960696648
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.4140331003018289
# attribute_name: VIDEOEND, attribute_error: 1.0954704247379918
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.0930634547459368
# attribute_name: VIDEOEND, attribute_error: 0.9941775960696648
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.4140331003018289
# attribute_name: VIDEOEND, attribute_error: 1.0954704247379918
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.9925857530935084
# attribute_name: VIDEOEND, attribute_error: 0.030940433927284645
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.517982566174309
# attribute_name: VIDEOEND, attribute_error: 0.9615050796106309
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.3149296206923011
# attribute_name: VIDEOEND, attribute_error: 0.044883037207663845
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002884087791495199
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.26459895390148874
# attribute_name: VIDEOEND, attribute_error: 1.7855608160243135
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.0503254940604125
# attribute_name: VIDEOEND, attribute_error: 1.2664451036557898
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.0633124958510387
# attribute_name: VIDEOEND, attribute_error: 2.161957272149454
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.0679696774543959
# attribute_name: VIDEOEND, attribute_error: 0.23328242861770557
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.2622324297435448
# attribute_name: VIDEOEND, attribute_error: 0.030260445147099514
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.9925857530935084
# attribute_name: VIDEOEND, attribute_error: 0.030940433927284645
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.517982566174309
# attribute_name: VIDEOEND, attribute_error: 0.9615050796106309
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.3149296206923011
# attribute_name: VIDEOEND, attribute_error: 0.044883037207663845
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002884087791495199
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.26459895390148874
# attribute_name: VIDEOEND, attribute_error: 1.7855608160243135
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.0503254940604125
# attribute_name: VIDEOEND, attribute_error: 1.2664451036557898
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 3.0633124958510387
# attribute_name: VIDEOEND, attribute_error: 2.161957272149454
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.0679696774543959
# attribute_name: VIDEOEND, attribute_error: 0.23328242861770557
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 0
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.2622324297435448
# attribute_name: VIDEOEND, attribute_error: 0.030260445147099514
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.2933826122116097
# attribute_name: VIDEOEND, attribute_error: 0.000688488639937441
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.3613729805876047
# attribute_name: VIDEOEND, attribute_error: 0.1111111111111111
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 2.40437130203659
# attribute_name: VIDEOEND, attribute_error: 0.0020862433547624245
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 8.621217333129872e-05
# attribute_name: VIDEOEND, attribute_error: 3.399943900925635e-05
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.4708227831186219
# attribute_name: VIDEOEND, attribute_error: 0.31990072163809297
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.4128390617011904
# attribute_name: VIDEOEND, attribute_error: 0.0015110861781891711
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.2933826122116097
# attribute_name: VIDEOEND, attribute_error: 0.000688488639937441
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.3613729805876047
# attribute_name: VIDEOEND, attribute_error: 0.1111111111111111
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 2.40437130203659
# attribute_name: VIDEOEND, attribute_error: 0.0020862433547624245
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 8.621217333129872e-05
# attribute_name: VIDEOEND, attribute_error: 3.399943900925635e-05
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.4708227831186219
# attribute_name: VIDEOEND, attribute_error: 0.31990072163809297
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.4128390617011904
# attribute_name: VIDEOEND, attribute_error: 0.0015110861781891711
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0026886145404663923
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.04640284017383823
# attribute_name: VIDEOEND, attribute_error: 2.5308511853998854
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0026886145404663923
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.171313071748357
# attribute_name: VIDEOEND, attribute_error: 0.005745905192564324
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0026886145404663923
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.04640284017383823
# attribute_name: VIDEOEND, attribute_error: 2.5308511853998854
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0026886145404663923
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.171313071748357
# attribute_name: VIDEOEND, attribute_error: 0.005745905192564324
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.026062802119785
# attribute_name: VIDEOEND, attribute_error: 0.010019445790255573
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.0899977498622757
# attribute_name: VIDEOEND, attribute_error: 0.04284779301141531
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 2.130461433415321
# attribute_name: VIDEOEND, attribute_error: 0.029588011797805337
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.006676270702775773
# attribute_name: VIDEOEND, attribute_error: 0.014521538172397933
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.3542294399053735
# attribute_name: VIDEOEND, attribute_error: 0.19295059409297524
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.30418758389522116
# attribute_name: VIDEOEND, attribute_error: 0.0076498737770826775
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002984396433470508
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.026062802119785
# attribute_name: VIDEOEND, attribute_error: 0.010019445790255573
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 2.0899977498622757
# attribute_name: VIDEOEND, attribute_error: 0.04284779301141531
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 2.130461433415321
# attribute_name: VIDEOEND, attribute_error: 0.029588011797805337
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.006676270702775773
# attribute_name: VIDEOEND, attribute_error: 0.014521538172397933
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.3542294399053735
# attribute_name: VIDEOEND, attribute_error: 0.19295059409297524
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.30418758389522116
# attribute_name: VIDEOEND, attribute_error: 0.0076498737770826775
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.566564850089962
# attribute_name: VIDEOEND, attribute_error: 0.2898603284156922
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.7359346994514322
# attribute_name: VIDEOEND, attribute_error: 0.08386906060494446
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.566564850089962
# attribute_name: VIDEOEND, attribute_error: 0.2898603284156922
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.7359346994514322
# attribute_name: VIDEOEND, attribute_error: 0.08386906060494446
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.0603071394887102
# attribute_name: VIDEOEND, attribute_error: 0.10535670605879449
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.2004183014650036
# attribute_name: VIDEOEND, attribute_error: 0.25341292979776947
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.0603071394887102
# attribute_name: VIDEOEND, attribute_error: 0.10535670605879449
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002408264746227709
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 1.2004183014650036
# attribute_name: VIDEOEND, attribute_error: 0.25341292979776947
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.13315383958845756
# attribute_name: VIDEOEND, attribute_error: 0.10789533083815227
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.002331177166878318
# attribute_name: VIDEOEND, attribute_error: 0.32210312974280364
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0025000000000000005
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 0
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.13315383958845756
# attribute_name: VIDEOEND, attribute_error: 0.10789533083815227
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 0.002593449931412894
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.002331177166878318
# attribute_name: VIDEOEND, attribute_error: 0.32210312974280364
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.35755291918729515
# attribute_name: VIDEOEND, attribute_error: 0.7197766236857092
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.0850017544177273
# attribute_name: VIDEOEND, attribute_error: 0.43542042667407094
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0027854938271604937
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.35755291918729515
# attribute_name: VIDEOEND, attribute_error: 0.7197766236857092
# attribute_name: concept:name, attribute_error: 0
# ...
# attribute_name: VIDEOSTART, attribute_error: 0.19956399413156672
# attribute_name: VIDEOEND, attribute_error: 0.4508469230201791
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.250997689561016e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.08650519031141869
# attribute_name: VIDEOEND, attribute_error: 0.7055642747743814
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 2.953686200378072e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.042159346933546525
# attribute_name: VIDEOEND, attribute_error: 0.31577110255864554
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.516829447595043e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.020340268119896383
# attribute_name: VIDEOEND, attribute_error: 0.5707035377983083
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.3135254206388019
# attribute_name: VIDEOEND, attribute_error: 0.14327895197533408
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.250997689561016e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.08650519031141869
# attribute_name: VIDEOEND, attribute_error: 0.7055642747743814
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 2.953686200378072e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.042159346933546525
# attribute_name: VIDEOEND, attribute_error: 0.31577110255864554
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.516829447595043e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.020340268119896383
# attribute_name: VIDEOEND, attribute_error: 0.5707035377983083
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.3135254206388019
# attribute_name: VIDEOEND, attribute_error: 0.14327895197533408
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 2.953686200378072e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.05827320981373515
# attribute_name: VIDEOEND, attribute_error: 0.7082461764741628
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 1.312749422390254e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.06687476364281393
# attribute_name: VIDEOEND, attribute_error: 0.015475836175911722
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 2.953686200378072e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.05827320981373515
# attribute_name: VIDEOEND, attribute_error: 0.7082461764741628
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 1.312749422390254e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.06687476364281393
# attribute_name: VIDEOEND, attribute_error: 0.015475836175911722
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 1.312749422390254e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.01686250694443589
# attribute_name: VIDEOEND, attribute_error: 0.10005904197123873
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 1.312749422390254e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.11685622461662402
# attribute_name: VIDEOEND, attribute_error: 0.21688555156195552
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.06516375318581771
# attribute_name: VIDEOEND, attribute_error: 0.005779556102732464
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 3.0795724567966784e-07
# attribute_name: VIDEOEND, attribute_error: 0.15351732156902978
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 1.312749422390254e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.01686250694443589
# attribute_name: VIDEOEND, attribute_error: 0.10005904197123873
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 1.312749422390254e-07
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.11685622461662402
# attribute_name: VIDEOEND, attribute_error: 0.21688555156195552
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.06516375318581771
# attribute_name: VIDEOEND, attribute_error: 0.005779556102732464
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 3.0795724567966784e-07
# attribute_name: VIDEOEND, attribute_error: 0.15351732156902978
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.7068311692151156
# attribute_name: VIDEOEND, attribute_error: 0.15813412673985155
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.07668166213148295
# attribute_name: VIDEOEND, attribute_error: 0.006444308215482563
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 0
# attribute_name: time:timestamp, attribute_error: 5.250997689561017e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 0
# attribute_name: VIDEOSTART, attribute_error: 0.7068311692151156
# attribute_name: VIDEOEND, attribute_error: 0.15813412673985155
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.07668166213148295
# attribute_name: VIDEOEND, attribute_error: 0.006444308215482563
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.9691648569045863
# attribute_name: VIDEOEND, attribute_error: 0.386234826510156
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.5992924990237755
# attribute_name: VIDEOEND, attribute_error: 0.007882343398166448
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.9691648569045863
# attribute_name: VIDEOEND, attribute_error: 0.386234826510156
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 1
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.5992924990237755
# attribute_name: VIDEOEND, attribute_error: 0.007882343398166448
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.05026354981085266
# attribute_name: VIDEOEND, attribute_error: 0.0144357478362347
# attribute_name: concept:name, attribute_error: 0
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 4.991729678638941e-05
# attribute_name: RESOURCE, attribute_error: 1
# attribute_name: ROUND, attribute_error: 0
# attribute_name: ACTIVITY, attribute_error: 1
# attribute_name: STAGE, attribute_error: 1
# attribute_name: VIDEOSTART, attribute_error: 0.05026354981085266
# attribute_name: VIDEOEND, attribute_error: 0.0144357478362347
# np.float64(0.3581842937937214)

# %%
len(trace_pairs)
# Out:
# 20

# %%
trace_mappings = maxes.metrics.mean_levenstein_distance.mean_levenstein_distance(eleven_processed, eleven_generated)
trace_mappings

trace_pairs = [(trace_pair.original_sequence.trace, trace_pair.generated_sequence.trace) for trace_pair in trace_mappings]
attribute_weights = get_attributes_weights1(eleven_processed)

[(trace_pair.original_sequence.index, trace_pair.generated_sequence.index) for trace_pair in trace_mappings]
# Out:
# [(0, 4),
#  (1, 0),
#  (2, 2),
#  (5, 3),
#  (9, 6),
#  (14, 7),
#  (7, 8),
#  (3, 1),
#  (6, 9),
#  (13, 5)]

# %%
len(eleven_processed.traces)
# Out:
# 3512

# %%
calculate_log_error(
    eleven_generated,
    trace_pairs,
    attribute_weights=attribute_weights
)
# Out:
# attribute_name: call centre, attribute_error: 1
# attribute_name: org:resource, attribute_error: 1
# attribute_name: time:timestamp, attribute_error: 0.0003635808675667912
# attribute_name: lifecycle:transition, attribute_error: 0
# attribute_name: concept:name, attribute_error: 0
# attribute_name: reason, attribute_error: 1
# attribute_name: check, attribute_error: 0
# attribute_name: age, attribute_error: 1
# attribute_name: pvr, attribute_error: 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 calculate_log_error(
#       2     eleven_generated,
#       3     trace_pairs,
#       4     attribute_weights=attribute_weights
#       5 )
#
# Cell In[16], line 130, in calculate_log_error(original_log, traces_pairs, attribute_weights)
#     127 accumulated_error = 0
#     129 for original_trace, generated_trace in traces_pairs:
# --> 130     trace_error = calculate_trace_error(
#     131         original_trace,
#     132         generated_trace,
#     133         event_attribute_type_map=original_log.event_attribute_type_map,
#     134         attributes_weights=attribute_weights
#     135     )
#     137     accumulated_error += trace_error
#     139 mean_log_error = accumulated_error / float(len(original_log.traces))
#
# Cell In[16], line 97, in calculate_trace_error(original_trace, generated_trace, event_attribute_type_map, attributes_weights)
#      89 accumulated_error = 0
#      91 for original_event in original_trace.events:
#      92     # TODO: Find best event by lowest error
#      94     generated_events_candidates = [
#      95         {
#      96             "event": event,
# ---> 97             "error": calculate_event_error(
#      98                 original_event=original_event,
#      99                 generated_event=event,
#     100                 event_attribute_type_map=event_attribute_type_map,
#     101                 attributes_range_lengths=attributes_range_lengths,
#     102                 attributes_weights=attributes_weights
#     103             )
#     104         }
#     105         for event in generated_trace.events
#     106         if event.concept_name == original_event.concept_name
#     107     ]
#     109     if len(generated_events_candidates) == 0:
#     110         # print('skipped event')
#     111         continue
#
# Cell In[16], line 58, in calculate_event_error(original_event, generated_event, event_attribute_type_map, attributes_range_lengths, attributes_weights)
#      55 attribute_error = 0
#      57 if attribute_type == XES_STRING:
# ---> 58     if original_event[attribute_name] != generated_event[attribute_name]:
#      59         attribute_error = 1
#      61 if attribute_type == XES_INT:
#
# File C:\vt\md\maxes\maxes\src\maxes\xes_loader2.py:42, in XesAttributesCollectionBase.__getitem__(self, key)
# ---> 42 def __getitem__(self, key): return self.attributes[key]
#
# KeyError: 'duration'

# %%
"C:\\vt\\md\\maxes\\maxes\\data\\other\\simple.xes"

# %%
simple_original_path = "C:\\vt\\md\\maxes\\maxes\\data\\other\\simple.xes"
simple_generated_path = "C:\\vt\\md\\maxes\\maxes\\output\\data_generated\\simple.xes"

simple_processed = maxes.notebooks.utils.load_xes(simple_original_path)
simple_processed

simple_generated = maxes.notebooks.utils.generate_log(simple_processed)
maxes.notebooks.utils.write_xes_to_file(simple_generated, skeleton_log=simple_processed, destination_file_path=simple_generated_path)

# %%
len(simple_generated.traces)
# Out:
# 3512

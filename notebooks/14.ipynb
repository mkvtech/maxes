# %%
# %load_ext autoreload
import ete3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
# %autoreload
from maxes.xes_file import XesFile
from maxes.print_xes_info import PrintXesInfo
import maxes.analyze_sequence
import maxes.graphs
import maxes.utils

# %%
xes = XesFile.read("../data/Activities of daily living of several individuals_1_all/data/edited_hh102_labour.xes/edited_hh102_labour.xes")

graph = maxes.analyze_sequence.analyze_xes_sequence(xes)
# graph = maxes.analyze_sequence.analyze_sequence(xes.traces[0].df)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 20)
fig.dpi = 70
# maxes.analyze_sequence.draw_nx_graph(graph, edge_label="frequency", ax=ax, pos=nx.circular_layout(graph))
maxes.analyze_sequence.draw_nx_graph(graph, edge_label="frequency", ax=ax, pos=nx.kamada_kawai_layout(graph))

# %%
path = maxes.graphs.random_weighted_traverse(
    graph, min_steps=90, max_steps=100, weight_feature_name="frequency")

print(len(path))
path
# Out:
# 98
# ['Start, start',
#  'Start, complete',
#  'sleep, start',
#  'sleep, complete',
#  'toilet, start',
#  'toilet, complete',
#  'personalhygiene, start',
#  'personalhygiene, complete',
#  'snack, start',
#  'snack, complete',
#  'relax, start',
#  'relax, complete',
#  'cleaning, start',
#  'cleaning, complete',
#  'read, start',
#  'read, complete',
#  'relax, start',
#  'relax, complete',
#  'toilet, start',
#  'toilet, complete',
#  'sleep, start',
#  'sleep, complete',
#  'toilet, start',
#  'toilet, complete',
#  'sleep, start',
#  'sleep, complete',
#  'toilet, start',
#  'toilet, complete',
#  'mealpreperation, start',
#  'mealpreperation, complete',
#  'eatingdrinking, start',
#  'eatingdrinking, complete',
#  'cleaning, start',
#  'cleaning, complete',
#  'read, start',
#  'read, complete',
#  'relax, start',
#  'relax, complete',
#  'personalhygiene, start',
#  'personalhygiene, complete',
#  'snack, start',
#  'snack, complete',
#  'personalhygiene, start',
# ...
